# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-np.pi,np.pi,256,endpoint=True)
y=np.sin(x)
plt.plot(x,y)

# %%
chart=plt.plot(x,y)
type(chart)
# Out:
# list

# %%
chart

# %%
for i in chart:
    print(i)
# Out:
# Line2D(_child0)
